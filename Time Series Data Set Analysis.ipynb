# %% [markdown]
# ## Time Series Data Analysis

# %% [markdown]
# ### DataSet : Plant_1 Generation Data
# ### DataSet Link: https://www.kaggle.com/code/pythonafroz/solar-power-generation-forecast
#
# ## Details about the dataset
# ###
# ## Number of columns: 7
#
#
# - 'DATE_TIME'
# - 'PLANT_ID',
# - 'SOURCE_KEY',
# - 'DC_POWER',
# - 'AC_POWER',
# - 'DAILY_YIELD',
# - 'TOTAL_YIELD'

# %%
import numpy as np
import pandas as pd
 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("Data/Plant_1_Generation_Data.csv")

# %%
df.columns
# Out:
# Index(['DATE_TIME', 'PLANT_ID', 'SOURCE_KEY', 'DC_POWER', 'AC_POWER',
#        'DAILY_YIELD', 'TOTAL_YIELD'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 68778 entries, 0 to 68777
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   DATE_TIME    68778 non-null  str
#  1   PLANT_ID     68778 non-null  int64
#  2   SOURCE_KEY   68778 non-null  str
#  3   DC_POWER     68778 non-null  float64
#  4   AC_POWER     68778 non-null  float64
#  5   DAILY_YIELD  68778 non-null  float64
#  6   TOTAL_YIELD  68778 non-null  float64
# dtypes: float64(4), int64(1), str(2)
# memory usage: 3.7 MB

# %%
df['DATE_TIME'].head()
# Out:
# 0    15-05-2020 00:00
# 1    15-05-2020 00:00
# 2    15-05-2020 00:00
# 3    15-05-2020 00:00
# 4    15-05-2020 00:00
# Name: DATE_TIME, dtype: str

# %%
df['DATE_TIME'] = pd.to_datetime(df['DATE_TIME'])

# %%
df=df.set_index(df['DATE_TIME'])

# %%
df.tail(5)
# Out:
#                               DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  \
# DATE_TIME
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  uHbuxQJl8lW7ozc       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  wCURE6d3bPkepu2       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  z9Y9gH1T5YWrNuG       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  zBIq5rxdHJRwDNY       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  zVJPv84UY57bAof       0.0
#
#                      AC_POWER  DAILY_YIELD  TOTAL_YIELD
# DATE_TIME
# 2020-06-17 23:45:00       0.0     5967.000    7287002.0
# 2020-06-17 23:45:00       0.0     5147.625    7028601.0
# 2020-06-17 23:45:00       0.0     5819.000    7251204.0
# 2020-06-17 23:45:00       0.0     5817.000    6583369.0
# 2020-06-17 23:45:00       0.0     5910.000    7363272.0

# %%
df.loc['2020-06-17 23:45:00']
# Out:
#                               DATE_TIME  PLANT_ID       SOURCE_KEY  DC_POWER  \
# DATE_TIME
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  1BY6WEcLGh8j5v7       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  1IF53ai7Xc0U56Y       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  3PZuoBAID5Wc2HD       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  7JYdWkrLSPkdwr4       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  McdE0feGgRqW7Ca       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  VHMLBKoKgIrUVDU       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  WRmjgnKYAwPKWDb       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  YxYtjZvoooNbGkE       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  ZnxXDlPa8U1GXgE       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  ZoEaEvLYb1n2sOq       0.0
# 2020-06-17 23:45:00 2020-06-17 23:45:00   4135001  adLQvlD726eNBSB       0.0
# ...

# %%
df.isnull().sum()
# Out:
# DATE_TIME      0
# PLANT_ID       0
# SOURCE_KEY     0
# DC_POWER       0
# AC_POWER       0
# DAILY_YIELD    0
# TOTAL_YIELD    0
# dtype: int64

# %%
df.dtypes
# Out:
# DATE_TIME      datetime64[us]
# PLANT_ID                int64
# SOURCE_KEY                str
# DC_POWER              float64
# AC_POWER              float64
# DAILY_YIELD           float64
# TOTAL_YIELD           float64
# dtype: object

# %%
sns.boxplot(data=df, x='DC_POWER')
# Out:
# <Axes: xlabel='DC_POWER'>

# %%
sns.boxplot(data=df, x='AC_POWER')
# Out:
# <Axes: xlabel='AC_POWER'>

# %%
sns.boxplot(data=df,x='DAILY_YIELD')
# Out:
# <Axes: xlabel='DAILY_YIELD'>

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
